# %%
import matplotlib.pyplot as plt

y = [50,51,52,45,46,48,55,54]
x=[1,2,3,4,5,6,7,8]

plt.plot(x,y)

# %%
plt.title("Weather Report")
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.plot(x,y , color="red" ,linewidth="2", linestyle="dashdot")
